# %% [markdown]
# FALHA DE REGISTRO CONTROLADORES

# %% [markdown]
# Este notebook tem como objetivo apresentar um script mais moderno e confiavel para apuração dos indicadores de falha de registro

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d3fb2d38-a78d-47f9-9f70-9f870c821320" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d3fb2d38-a78d-47f9-9f70-9f870c821320">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ANALISADAS.csv to ANALISADAS (2).csv

# %%
import pandas as pd
import numpy as np
import statistics as sts

# %%
dbpos = pd.read_csv("ANALISADAS (1).csv", sep=",")
dbpos.head()
# Out:
#          ID OCO_DATA_NR TB_TP_ABRANGENCIA  OBS_DATA  OCO_NUMERO  \
# 0  15160336    03/01/22                AL  05/01/22       11009
# 1  15160336    03/01/22                AL  05/01/22       11009
# 2  15161101    05/01/22                SE  06/01/22       11774
# 3  15161101    05/01/22                SE  06/01/22       11774
# 4  15161098    05/01/22                AL  06/01/22       11771
#
#                   ANALISTA                                         OBSERVACAO
# 0  IRACY OLIVEIRA DA SILVA                                          #VALIDADO
# 1  IRACY OLIVEIRA DA SILVA  CORREÇÃO: Corrigido os tempos operacionais de ...
# 2  IRACY OLIVEIRA DA SILVA  CORREÇÃO: Corrigido os eventos de acordo com h...
# 3  IRACY OLIVEIRA DA SILVA                                          #VALIDADO
# 4  IRACY OLIVEIRA DA SILVA                                          #VALIDADO

# %%
#alterar coluna para fazer cruzamento
dbpos = dbpos.rename(columns={"OCO_DATA_NR":"DATA"})

# %%
dbpos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3552 entries, 0 to 3551
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 3552 non-null   int64
#  1   DATA               3552 non-null   object
#  2   TB_TP_ABRANGENCIA  3552 non-null   object
#  3   OBS_DATA           3552 non-null   object
#  4   OCO_NUMERO         3552 non-null   int64
#  5   ANALISTA           3552 non-null   object
#  6   OBSERVACAO         3552 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 194.4+ KB

# %%
#transformando serie de data de objeto para datatime
dbpos["DATA"] = pd.to_datetime(dbpos["DATA"], dayfirst = True )
dbpos.head()
# Out:
#          ID       DATA TB_TP_ABRANGENCIA  OBS_DATA  OCO_NUMERO  \
# 0  15160336 2022-01-03                AL  05/01/22       11009
# 1  15160336 2022-01-03                AL  05/01/22       11009
# 2  15161101 2022-01-05                SE  06/01/22       11774
# 3  15161101 2022-01-05                SE  06/01/22       11774
# 4  15161098 2022-01-05                AL  06/01/22       11771
#
#                   ANALISTA                                         OBSERVACAO
# 0  IRACY OLIVEIRA DA SILVA                                          #VALIDADO
# 1  IRACY OLIVEIRA DA SILVA  CORREÇÃO: Corrigido os tempos operacionais de ...
# 2  IRACY OLIVEIRA DA SILVA  CORREÇÃO: Corrigido os eventos de acordo com h...
# 3  IRACY OLIVEIRA DA SILVA                                          #VALIDADO
# 4  IRACY OLIVEIRA DA SILVA                                          #VALIDADO

# %%
dbpos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3552 entries, 0 to 3551
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 3552 non-null   int64
#  1   DATA               3552 non-null   datetime64[ns]
#  2   TB_TP_ABRANGENCIA  3552 non-null   object
#  3   OBS_DATA           3552 non-null   object
#  4   OCO_NUMERO         3552 non-null   int64
#  5   ANALISTA           3552 non-null   object
#  6   OBSERVACAO         3552 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 194.4+ KB

# %%
dbpos['mes'] = dbpos.DATA.dt.month
dbpos
# Out:
#             ID       DATA TB_TP_ABRANGENCIA  OBS_DATA  OCO_NUMERO  \
# 0     15160336 2022-01-03                AL  05/01/22       11009
# 1     15160336 2022-01-03                AL  05/01/22       11009
# 2     15161101 2022-01-05                SE  06/01/22       11774
# 3     15161101 2022-01-05                SE  06/01/22       11774
# 4     15161098 2022-01-05                AL  06/01/22       11771
# ...        ...        ...               ...       ...         ...
# 3547  15282891 2022-02-16                TF  15/03/22       45816
# 3548  15275982 2022-02-13                CH  15/03/22       38882
# 3549  15275982 2022-02-13                CH  15/03/22       38882
# 3550  15281459 2022-02-15                CH  15/03/22       44380
# 3551  15281459 2022-02-15                CH  15/03/22       44380
#
#                               ANALISTA  \
# 0              IRACY OLIVEIRA DA SILVA
# 1              IRACY OLIVEIRA DA SILVA
# 2              IRACY OLIVEIRA DA SILVA
# ...

# %%
ag = dbpos.groupby(["mes"]).size()
ag
# Out:
# mes
# 1    1136
# 2    1048
# 3    1368
# dtype: int64

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a51bb5d6-0e0e-4119-98e5-87e812e06bcd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a51bb5d6-0e0e-4119-98e5-87e812e06bcd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving JANEIRO_2022.csv to JANEIRO_2022 (1).csv

# %%
dfjan = pd.read_csv("JANEIRO_2022 (1).csv", sep=";")
dfjan.head()
# Out:
#    OCORRENCIA  OCORRENCIA_ID        TIPO        DATA      REGIONAL  \
# 0           2       15149383    COLETIVO  01/01/2022  CENTRO-OESTE
# 1           3       15149384  INDIVIDUAL  01/01/2022      NORDESTE
# 2           3       15236295  INDIVIDUAL  31/01/2022         NORTE
# 3           4       15236296  INDIVIDUAL  31/01/2022         NORTE
# 4           6       15149387  INDIVIDUAL  01/01/2022      NORDESTE
#
#                POLO    LOCALIDADE                         USUARIO     LOGIN  \
# 0          ALTAMIRA  MEDICILANDIA  ERNESTO VON MANSTEIN LEAO MAIA  u1007649
# 1          CAPANEMA   SALINOPOLIS     FABIANA FERREIRA DOS SANTOS  u1009847
# 2  EM ANALISE NORTE    EM ANALISE          Rodrigo da Silva Mandu  u1009573
# 3  EM ANALISE NORTE    EM ANALISE          Rodrigo da Silva Mandu  u1009573
# 4       PARAGOMINAS   PARAGOMINAS     SANDRA MARIA FREITAS NEGRAO  u1009407
#
#      EQUIPE  DESPACHO ABRANGENCIA
# 0    MED301    NORMAL          CH
# 1  PAR001bx    NORMAL          CR
# ...

# %%
dfjan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50386 entries, 0 to 50385
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OCORRENCIA     50386 non-null  int64
#  1   OCORRENCIA_ID  50386 non-null  int64
#  2   TIPO           50386 non-null  object
#  3   DATA           50386 non-null  object
#  4   REGIONAL       50386 non-null  object
#  5   POLO           50386 non-null  object
#  6   LOCALIDADE     50386 non-null  object
#  7   USUARIO        50386 non-null  object
#  8   LOGIN          50386 non-null  object
#  9   EQUIPE         50386 non-null  object
#  10  DESPACHO       50386 non-null  object
#  11  ABRANGENCIA    50386 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 4.6+ MB

# %%
dfjan["DATA"] = pd.to_datetime(dfjan["DATA"], dayfirst = True )
dfjan = dfjan.rename(columns={"OCORRENCIA_ID":"ID"})
dfjan
# Out:
#        OCORRENCIA        ID        TIPO       DATA      REGIONAL  \
# 0               2  15149383    COLETIVO 2022-01-01  CENTRO-OESTE
# 1               3  15149384  INDIVIDUAL 2022-01-01      NORDESTE
# 2               3  15236295  INDIVIDUAL 2022-01-31         NORTE
# 3               4  15236296  INDIVIDUAL 2022-01-31         NORTE
# 4               6  15149387  INDIVIDUAL 2022-01-01      NORDESTE
# ...           ...       ...         ...        ...           ...
# 50381       90359  15149057    COLETIVO 2022-01-01      NORDESTE
# 50382       90381  15149079    COLETIVO 2022-01-01         OESTE
# 50383       90589  15149287    COLETIVO 2022-01-01      NORDESTE
# 50384       90653  15149351    COLETIVO 2022-01-02      NORDESTE
# 50385       90664  15149362  INDIVIDUAL 2022-01-01      NORDESTE
#
#                       POLO           LOCALIDADE  \
# 0                 ALTAMIRA         MEDICILANDIA
# 1                 CAPANEMA          SALINOPOLIS
# ...
